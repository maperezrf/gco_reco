# %%
import pandas as pd

# %%
df = pd.read_csv('220718_f4.csv', dtype='object')

# %%
pd.set_option('display.max_columns', 200)

# %%
df.head()
# Out:
#   CTECH_KEY PRD_LVL_CHILD        PRD_UPC QF04_SHIP MF04_UNIT_CST TOTAL_COSTO  \
# 0  46796042       3100288  2077032834000        10      2609.956       26100
# 1  46779373       4795990  2004037809009        20      1883.218       37664
# 2  46663641       3184036  8411061783382         1       781.016         781
# 3  46788320       4572891  2003865971001       100        413.18       41318
# 4  46726148      21059791   602004129253         1     48335.015       48335
#
#   CESTADO DESCESTADO USR_REGISTRO       FECHA_REGISTRO USR_RESERVA  \
# 0       2  Reservado     YMENESES  2022-06-03 11:47:04    YMENESES
# 1       2  Reservado     AHIGUERA  2022-05-09 12:10:25     YALOPEZ
# 2       2  Reservado     JECAMPOS  2022-01-05 09:23:11    JECAMPOS
# 3       2  Reservado     AHIGUERA  2022-05-21 19:12:25     YALOPEZ
# 4       2  Reservado     HJIMENEZ  2022-02-26 08:57:29    HJIMENEZ
#
#          FECHA_RESERVA USR_ENVIO FECHA_ENVIO USR_ANULADO FECHA_ANULADO  \
# ...

# %%
df['XDESTINO'].str.lower()
# Out:
# 0                                  NaN
# 1                                  NaN
# 2                               tester
# 3                                  NaN
# 4           bajas por muestras/ tester
#                      ...
# 75306                              NaN
# 75307    merma por daño/averia interna
# 75308                              NaN
# 75309                              NaN
# 75310                    f04 x calidad
# Name: XDESTINO, Length: 75311, dtype: object

# %%
df.columns
# Out:
# Index(['CTECH_KEY', 'PRD_LVL_CHILD', 'PRD_UPC', 'QF04_SHIP', 'MF04_UNIT_CST',
#        'TOTAL_COSTO', 'CESTADO', 'DESCESTADO', 'USR_REGISTRO',
#        'FECHA_REGISTRO', 'USR_RESERVA', 'FECHA_RESERVA', 'USR_ENVIO',
#        'FECHA_ENVIO', 'USR_ANULADO', 'FECHA_ANULADO', 'PROD_CAT_ID',
#        'PROD_CAT_DESC', 'PROD_NAME', 'PROD_BRAND_ID', 'LOC_ID', 'LOC_NAME',
#        'LOCAL_AGG', 'CTIPO', 'DESCTIPO', 'CCENT_COSTO_F', 'XDESTINO', 'TNOTAS',
#        'COPERARIO', 'NFORMULARIO', 'BMARGEN', 'POSIBLE_CAUSA'],
#       dtype='object')
